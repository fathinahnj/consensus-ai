# %% [markdown]
# <a href="https://colab.research.google.com/github/fathinahnj/consensus-ai/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U mesa[rec]
# Out:
# Collecting mesa[rec]
#   Downloading mesa-3.4.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (4.67.1)
# Requirement already satisfied: altair in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (5.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from mesa[rec]) (3.6.1)
# Collecting solara (from mesa[rec])
#   Downloading solara-1.56.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair->mesa[rec]) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair->mesa[rec]) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair->mesa[rec]) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from altair->mesa[rec]) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from altair->mesa[rec]) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mesa[rec]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->mesa[rec]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->mesa[rec]) (2025.3)
# Collecting solara-server==1.56.0 (from solara-server[dev,starlette]==1.56.0->solara->mesa[rec])
#   Downloading solara_server-1.56.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.56.0 (from solara-ui[all]==1.56.0->solara->mesa[rec])
#   Downloading solara_ui-1.56.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: click>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (3.20.2)
# Requirement already satisfied: ipykernel!=7.0.0,!=7.0.1 in /usr/local/lib/python3.12/dist-packages (from solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (6.17.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.12/dist-packages (from solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (7.4.9)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (5.10.4)
# Collecting rich-click (from solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec])
#   Downloading rich_click-1.9.5-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (6.0.0)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (1.1.1)
# Requirement already satisfied: starlette in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.50.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.40.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (4.15.0)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec])
#   Downloading ipyvue-1.11.3-py2.py3-none-any.whl.metadata (987 bytes)
# Collecting ipyvuetify>=1.6.10 (from solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec])
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.12/dist-packages (from solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (7.7.1)
# Collecting reacton>=1.9 (from solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec])
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.32.4)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.56.0->solara->mesa[rec]) (6.2.4)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.56.0->solara->mesa[rec]) (3.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.56.0->solara->mesa[rec]) (2.19.2)
# Collecting pymdown-extensions (from solara-ui[all]==1.56.0->solara->mesa[rec])
#   Downloading pymdown_extensions-10.20-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mesa[rec]) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair->mesa[rec]) (3.0.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (3.0.16)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (5.9.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (2.21.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pymdown-extensions->solara-ui[all]==1.56.0->solara->mesa[rec]) (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2026.1.4)
# Requirement already satisfied: rich>=12 in /usr/local/lib/python3.12/dist-packages (from rich-click->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (13.9.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (4.12.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.16.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (4.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->rich-click->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (4.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12->rich-click->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (25.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.0.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.56.0->solara-server[dev,starlette]==1.56.0->solara->mesa[rec]) (0.2.14)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.8.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (2.23)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.56.0->solara-ui[all]==1.56.0->solara->mesa[rec]) (1.4.0)
# Downloading mesa-3.4.1-py3-none-any.whl (241 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.9/241.9 kB 8.4 MB/s eta 0:00:00
# Downloading solara-1.56.0-py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.56.0-py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.56.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.8 MB/s eta 0:00:00
# Downloading ipyvue-1.11.3-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 21.6 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 47.6 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.2 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.20-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 19.3 MB/s eta 0:00:00
# Downloading rich_click-1.9.5-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 6.1 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.4 MB/s eta 0:00:00
# Installing collected packages: pymdown-extensions, jedi, rich-click, mesa, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara
# Successfully installed ipyvue-1.11.3 ipyvuetify-1.11.3 jedi-0.19.2 mesa-3.4.1 pymdown-extensions-10.20 reacton-1.9.1 rich-click-1.9.5 solara-1.56.0 solara-server-1.56.0 solara-ui-1.56.0

# %% [markdown]
# # Static Attributes

# %%
AGE_GROUPS = {
    "GenZ":       {"ratio": 0.2494, "digital_exposure": 0.48},
    "Millennial": {"ratio": 0.3344, "digital_exposure": 0.40},
    "GenX":       {"ratio": 0.2705, "digital_exposure": 0.32},
    "Boomer":     {"ratio": 0.1308, "digital_exposure": 0.22},
    "PreBoomer":  {"ratio": 0.0149, "digital_exposure": 0.12},
}

EDUCATION_LEVELS = {
    "PrimaryAndLower": {
        "ratio": 0.238,
        "cognitive_complexity": 0.30,
    },
    "SecondaryLevel": {
        "ratio": 0.61,
        "cognitive_complexity": 0.50,
    },
    "University": {
        "ratio": 0.148,
        "cognitive_complexity": 0.75,
    }
}

INCOME_LEVELS = {
    "Poor": {
        "ratio": 0.233,
        "economic_anxiety": 0.78,
        "welfare_salience": 0.80,
        "status_quo_bias": 0.25,
    },
    "Vulnerable": {
        "ratio": 0.536,
        "economic_anxiety": 0.65,
        "welfare_salience": 0.68,
        "status_quo_bias": 0.40,
    },
    "MiddleUpper": {
        "ratio": 0.139,
        "economic_anxiety": 0.35,
        "welfare_salience": 0.42,
        "status_quo_bias": 0.65,
    }
}
